# %%
pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')

# %%
results = model.predict('/content/input-video/video.mp4', save=True)
print(results[0])
print('/n')
for box in results[0].boxes:
    print(box)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/750) /content/video.mp4: 384x640 21 persons, 96.4ms
# video 1/1 (frame 2/750) /content/video.mp4: 384x640 21 persons, 9.4ms
# video 1/1 (frame 3/750) /content/video.mp4: 384x640 22 persons, 9.7ms
# video 1/1 (frame 4/750) /content/video.mp4: 384x640 23 persons, 8.9ms
# video 1/1 (frame 5/750) /content/video.mp4: 384x640 22 persons, 8.7ms
# video 1/1 (frame 6/750) /content/video.mp4: 384x640 23 persons, 11.6ms
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="a7Cl78F0ODixex6acDda")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.8
#     Uninstalling idna-3.8:
#       Successfully uninstalled idna-3.8
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.85, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to football-players-detection-1 in yolov8:: 100%|██████████| 1338/1338 [00:03<00:00, 366.84it/s]

# %%
dataset.location
# Out:
# '/content/football-players-detection-1'

# %%
import shutil
shutil.move('football-players-detection-1/train','football-players-detection-1/football-players-detection-1/train')
shutil.move('football-players-detection-1/test','football-players-detection-1/football-players-detection-1/test')
shutil.move('football-players-detection-1/valid','football-players-detection-1/football-players-detection-1/valid')
# Out:
# 'football-players-detection-1/football-players-detection-1/valid'

# %%
# training
# !yolo train data=/content/football-players-detection-1/data.yaml model=yolov8n.pt epochs=100 imgsz=640
# Out:
# Ultralytics YOLOv8.2.85 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model = YOLO('/content/runs/detect/train/weights/best.pt')

# %%
results = model.predict('/content/input-video/video.mp4', save=True)
print(results[0])
print('/n')
for box in results[0].boxes:
    print(box)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/750) /content/input-video/video.mp4: 384x640 1 goalkeeper, 17 players, 3 referees, 10.6ms
# video 1/1 (frame 2/750) /content/input-video/video.mp4: 384x640 1 goalkeeper, 17 players, 3 referees, 9.3ms
# video 1/1 (frame 3/750) /content/input-video/video.mp4: 384x640 1 goalkeeper, 19 players, 3 referees, 9.5ms
# ...

# %%
import shutil

# Define the directory to zip
folder_to_zip = '/content/runs'  # Change to your folder
output_zip = '/content/runs.zip'  # Name for the output zip file

# Create a zip file
shutil.make_archive(output_zip.replace('.zip', ''), 'zip', folder_to_zip)
# Out:
# '/content/runs.zip'
